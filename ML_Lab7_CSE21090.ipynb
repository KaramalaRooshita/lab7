# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("NID_data.csv")
data
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data    SF        491          0     0
# 1             0           udp     other    SF        146          0     0
# 2             0           tcp   private    S0          0          0     0
# 3             0           tcp      http    SF        232       8153     0
# 4             0           tcp      http    SF        199        420     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %% [markdown]
# # A1

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import StandardScaler as ss
from sklearn.svm import SVC

class1 = "normal"
class2 = "anomaly"
selected_data = data[(data['class'] == class1) | (data['class'] == class2)]
selected_data = pd.get_dummies(selected_data, columns=['protocol_type', 'service', 'flag'])

X = selected_data.drop(columns=['class'])
y = selected_data['class']
X_train, X_test, y_train, y_test = tts(X, y, test_size=0.3, random_state=42)

scaler = ss()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

svm_model = SVC(kernel='linear', C=1.0)  
svm_model.fit(X_train, y_train)

accuracy = svm_model.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9763164858428156

# %%
from sklearn import svm

clf = svm.SVC()
clf.fit(X_train, y_train)
support_vector_indices = clf.support_

support_vectors = X_train[support_vector_indices]

print("Support vectors :", support_vectors)
# Out:
# Support vectors : [[-0.11653224 -0.01049003 -0.04098783 ... -0.02259731 -1.21347362
#   -0.04196503]
#  [-0.11653224 -0.01047475 -0.03825929 ... -0.02259731  0.82408054
#   -0.04196503]
#  [-0.11475609 -0.01049003 -0.04098783 ... -0.02259731  0.82408054
#   -0.04196503]
#  ...
#  [-0.11653224 -0.01043758 -0.04098783 ... -0.02259731  0.82408054
#   -0.04196503]
#  [-0.11653224 -0.01047961 -0.04098783 ... -0.02259731  0.82408054
#   -0.04196503]
#  [-0.10694103 -0.01007977  0.00704573 ... -0.02259731  0.82408054
#   -0.04196503]]

# %% [markdown]
# # A2

# %%
from sklearn import svm
accuracy = clf.score(X_test, y_test)

print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9888859486636676

# %% [markdown]
# # A3

# %%
from sklearn.svm import SVC

svm = SVC(kernel='linear', C=1)
svm.fit(X_train, y_train)
predicted_labels = svm.predict(X_test)
decision_values = svm.decision_function(X_test)

accuracy = (predicted_labels == y_test).mean()

print("Predicted Labels:", predicted_labels)
print("\nTrue Labels:", y_test)
print("\nDecision Function Values:", decision_values)
print(f"\nAccuracy: {accuracy * 100:.2f}%")
# Out:
# Predicted Labels: ['anomaly' 'normal' 'anomaly' ... 'normal' 'anomaly' 'anomaly']
#
# True Labels: 19064    anomaly
# 11127     normal
# 6517     anomaly
# 2973      normal
# 13339    anomaly
#           ...
# 15322    anomaly
# 24483    anomaly
# 6778      normal
# 9500     anomaly
# 19865    anomaly
# Name: class, Length: 7558, dtype: object
#
# Decision Function Values: [-1.2091449   3.29852355 -5.83970273 ...  1.10856699 -6.58418626
#  -6.26294681]
#
# Accuracy: 97.63%

# %% [markdown]
# # A4

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

kernel_functions = ['linear', 'poly', 'rbf', 'sigmoid']

for kernel_func in kernel_functions:
    svm_classifier = SVC(kernel=kernel_func)
    svm_classifier.fit(X_train, y_train)
    y_pred_svm = svm_classifier.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred_svm)

    print(f"Kernel: {kernel_func}, Accuracy: {accuracy:.2f}")
# Out:
# Kernel: linear, Accuracy: 0.98
# Kernel: poly, Accuracy: 0.98
# Kernel: rbf, Accuracy: 0.99
# Kernel: sigmoid, Accuracy: 0.94
